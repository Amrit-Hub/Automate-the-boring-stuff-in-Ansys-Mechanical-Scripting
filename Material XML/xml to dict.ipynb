# %%
# Import the required modules
import xmltodict

# Open the file and read the contents
with open('Structural Steel.xml', 'r', encoding='utf-8') as file:
	my_xml = file.read()

# Use xmltodict to parse and convert the
# XML document
my_dict = xmltodict.parse(my_xml)

print(my_dict)
# Out:
# {'EngineeringData': {'@version': '21.2.0.240', '@versiondate': '01-06-2021 14:03:00', 'Notes': None, 'Materials': {'MatML_Doc': {'Material': {'BulkDetails': {'Name': 'Structural Steel', 'Description': 'Fatigue Data at zero mean stress comes from 1998 ASME BPV Code, Section 8, Div 2, Table 5-110.1', 'Class': {'Name': 'Alloy'}, 'PropertyData': [{'@property': 'pr0', 'Data': {'@format': 'string', '#text': '-'}, 'ParameterValue': [{'@parameter': 'pa0', '@format': 'float', 'Data': '132', 'Qualifier': {'@name': 'Variable Type', '#text': 'Dependent'}}, {'@parameter': 'pa1', '@format': 'float', 'Data': '139', 'Qualifier': {'@name': 'Variable Type', '#text': 'Dependent'}}, {'@parameter': 'pa2', '@format': 'float', 'Data': '179', 'Qualifier': {'@name': 'Variable Type', '#text': 'Dependent'}}, {'@parameter': 'pa3', '@format': 'string', 'Data': 'Appearance'}]}, {'@property': 'pr1', 'Data': {'@format': 'string', '#text': '-'}, 'ParameterValue': {'@parameter': 'pa4', '@format': 'float', 'Data': '0', 'Qualifier': {'@name': 'Variable Type', '#text': 'Dependent'}}}, {'@property': 'pr2', 'Data': {'@format': 'string', '#text': '-'}, 'ParameterValue': {'@parameter': 'pa5', '@format': 'float', 'Data': '250000000', 'Qualifier': {'@name': 'Variable Type', '#text': 'Dependent'}}}, {'@property': 'pr3', 'Data': {'@format': 'string', '#text': '-'}, 'Qualifier': {'@name': 'Field Variable Compatible', '#text': 'Temperature'}, 'ParameterValue': [{'@parameter': 'pa6', '@format': 'string', 'Data': 'Interpolation Options', 'Qualifier': [{'@name': 'AlgorithmType', '#text': 'Linear Multivariate'}, {'@name': 'Normalized', '#text': 'True'}, {'@name': 'Cached', '#text': 'True'}, {'@name': 'BETA', '#text': 'AlgorithmType$$Linear Multivariate (CGAL)$$EngineeringData.CGAL'}]}, {'@parameter': 'pa7', '@format': 'float', 'Data': '7850', 'Qualifier': {'@name': 'Variable Type', '#text': 'Dependent'}}, {'@parameter': 'pa8', '@format': 'float', 'Data': '7.88860905221012e-31', 'Qualifier': [{'@name': 'Variable Type', '#text': 'Independent'}, {'@name': 'Field Variable', '#text': 'Temperature'}, {'@name': 'Default Data', '#text': '22'}, {'@name': 'Field Units', '#text': 'C'}, {'@name': 'Upper Limit', '#text': 'Program Controlled'}, {'@name': 'Lower Limit', '#text': 'Program Controlled'}]}]}, {'@property': 'pr4', 'Data': {'@format': 'string', '#text': '-'}, 'ParameterValue': {'@parameter': 'pa9', '@format': 'float', 'Data': '250000000', 'Qualifier': {'@name': 'Variable Type', '#text': 'Dependent'}}}, {'@property': 'pr5', 'Data': {'@format': 'string', '#text': '-'}, 'ParameterValue': {'@parameter': 'pa10', '@format': 'float', 'Data': '460000000', 'Qualifier': {'@name': 'Variable Type', '#text': 'Dependent'}}}, {'@property': 'pr6', 'Data': {'@format': 'string', '#text': '-'}, 'Qualifier': [{'@name': 'Definition', '#text': 'Secant'}, {'@name': 'Behavior', '#text': 'Isotropic'}, {'@name': 'Field Variable Compatible', '#text': 'Temperature'}], 'ParameterValue': [{'@parameter': 'pa6', '@format': 'string', 'Data': 'Interpolation Options', 'Qualifier': [{'@name': 'AlgorithmType', '#text': 'Linear Multivariate'}, {'@name': 'Normalized', '#text': 'True'}, {'@name': 'Cached', '#text': 'True'}, {'@name': 'BETA', '#text': 'AlgorithmType$$Linear Multivariate (CGAL)$$EngineeringData.CGAL'}]}, {'@parameter': 'pa11', '@format': 'float', 'Data': '1.2e-05', 'Qualifier': {'@name': 'Variable Type', '#text': 'Dependent'}}, {'@parameter': 'pa8', '@format': 'float', 'Data': '7.88860905221012e-31', 'Qualifier': [{'@name': 'Variable Type', '#text': 'Independent'}, {'@name': 'Field Variable', '#text': 'Temperature'}, {'@name': 'Default Data', '#text': '22'}, {'@name': 'Field Units', '#text': 'C'}, {'@name': 'Upper Limit', '#text': 'Program Controlled'}, {'@name': 'Lower Limit', '#text': 'Program Controlled'}]}]}, {'@property': 'pr7', 'Data': {'@format': 'string', '#text': '-'}, 'Qualifier': [{'@name': 'Definition', '#text': 'Secant'}, {'@name': 'Behavior', '#text': 'Isotropic'}], 'ParameterValue': [{'@par ...

# %%
import dicttoxml
xml = dicttoxml.dicttoxml(my_dict)
print(xml)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" ?><root><EngineeringData type="dict"><key name="@version" type="str">21.2.0.240</key><key name="@versiondate" type="str">01-06-2021 14:03:00</key><Notes type="null"></Notes><Materials type="dict"><MatML_Doc type="dict"><Material type="dict"><BulkDetails type="dict"><Name type="str">Structural Steel</Name><Description type="str">Fatigue Data at zero mean stress comes from 1998 ASME BPV Code, Section 8, Div 2, Table 5-110.1</Description><Class type="dict"><Name type="str">Alloy</Name></Class><PropertyData type="list"><item type="dict"><key name="@property" type="str">pr0</key><Data type="dict"><key name="@format" type="str">string</key><key name="#text" type="str">-</key></Data><ParameterValue type="list"><item type="dict"><key name="@parameter" type="str">pa0</key><key name="@format" type="str">float</key><Data type="str">132</Data><Qualifier type="dict"><key name="@name" type="str">Variable Type</key><key name="#text" type="str">Dependent</key></Qualifier></item><item type="dict"><key name="@parameter" type="str">pa1</key><key name="@format" type="str">float</key><Data type="str">139</Data><Qualifier type="dict"><key name="@name" type="str">Variable Type</key><key name="#text" type="str">Dependent</key></Qualifier></item><item type="dict"><key name="@parameter" type="str">pa2</key><key name="@format" type="str">float</key><Data type="str">179</Data><Qualifier type="dict"><key name="@name" type="str">Variable Type</key><key name="#text" type="str">Dependent</key></Qualifier></item><item type="dict"><key name="@parameter" type="str">pa3</key><key name="@format" type="str">string</key><Data type="str">Appearance</Data></item></ParameterValue></item><item type="dict"><key name="@property" type="str">pr1</key><Data type="dict"><key name="@format" type="str">string</key><key name="#text" type="str">-</key></Data><ParameterValue type="dict"><key name="@parameter" type="str">pa4</key><key name="@format" type="str">float</key><Data type="str">0</Data><Qualifier type="dict"><key name="@name" type="str">Variable Type</key><key name="#text" type="str">Dependent</key></Qualifier></ParameterValue></item><item type="dict"><key name="@property" type="str">pr2</key><Data type="dict"><key name="@format" type="str">string</key><key name="#text" type="str">-</key></Data><ParameterValue type="dict"><key name="@parameter" type="str">pa5</key><key name="@format" type="str">float</key><Data type="str">250000000</Data><Qualifier type="dict"><key name="@name" type="str">Variable Type</key><key name="#text" type="str">Dependent</key></Qualifier></ParameterValue></item><item type="dict"><key name="@property" type="str">pr3</key><Data type="dict"><key name="@format" type="str">string</key><key name="#text" type="str">-</key></Data><Qualifier type="dict"><key name="@name" type="str">Field Variable Compatible</key><key name="#text" type="str">Temperature</key></Qualifier><ParameterValue type="list"><item type="dict"><key name="@parameter" type="str">pa6</key><key name="@format" type="str">string</key><Data type="str">Interpolation Options</Data><Qualifier type="list"><item type="dict"><key name="@name" type="str">AlgorithmType</key><key name="#text" type="str">Linear Multivariate</key></item><item type="dict"><key name="@name" type="str">Normalized</key><key name="#text" type="str">True</key></item><item type="dict"><key name="@name" type="str">Cached</key><key name="#text" type="str">True</key></item><item type="dict"><key name="@name" type="str">BETA</key><key name="#text" type="str">AlgorithmType$$Linear Multivariate (CGAL)$$EngineeringData.CGAL</key></item></Qualifier></item><item type="dict"><key name="@parameter" type="str">pa7</key><key name="@format" type="str">float</key><Data type="str">7850</Data><Qualifier type="dict"><key name="@name" type="str">Variable Type</key><key name="#text" type="str">Dependent</key></Qualifier></item><item type="dict"><key name="@parameter" type="str">pa8</key><key name="@format"  ...
